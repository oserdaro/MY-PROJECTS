# %% [markdown]
# # PART- 3 ( Handling the Outliers )

# %% [markdown]
# ## Importing the necessary Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats.mstats import winsorize
import scipy.stats

import warnings
warnings.filterwarnings("ignore")  # to suppress all warnings

# %% [markdown]
# ## Reading the csv file

# %%
df0=pd.read_csv('df_cleaned_no_missing_val.csv')
df0.head().T
# Out:
#                                                                        0  \
# Unnamed: 0                                                             0
# make_model                                           Mercedes-Benz A 160
# make                                                       Mercedes-Benz
# location               P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# price                                                              16950
# body_type                                                        Compact
# type                                                                Used
# doors                                                                  5
# warranty                                                               2
# mileage                                                         120200.0
# first_registration                                            2016-06-01
# gearbox                                                           Manual
# fuel_type                                                         diesel
# colour                                                              Grey
# paint                                                           Metallic
# seller                                                            Dealer
# seats                                                                  5
# power                                                                 81
# engine_size                                                         1461
# co_emissions                                                         131
# drivetrain                                                         Front
# fuel_consumption                                                     3.8
# comfort_convenience                                                  Low
# entertainment_media                                                  Low
# safety_security                                                   Medium
# extras                                                               Low
# general_inspection                                                     0
# last_service                                                           0
# full_service_history                                                   0
# non_smoker_vehicle                                                     0
# emission_class                                                         6
# upholstery                                                         Cloth
# previous_owner                                                         0
# taxi_or_rental_car                                                     0
# country                                                               ES
# age                                                                  6.0
# comfort_convenience_n                                                  1
# safety_security_n                                                      2
# entertainment_media_n                                                  1
# extras_n                                                               1
#
#                                                                   1  \
# Unnamed: 0                                                        1
# make_model                                    Mercedes-Benz EQE 350
# make                                                  Mercedes-Benz
# location               APARTADO DE CORREOS 1032,  26140 LOGROÑO, ES
# price                                                         80900
# body_type                                                   Compact
# type                                                 Pre-registered
# doors                                                             4
# warranty                                                          2
# mileage                                                      5000.0
# first_registration                                       2022-06-01
# gearbox                                                   Automatic
# fuel_type                                                  electric
# colour                                                       Others
# paint                                                         Basic
# seller                                                       Dealer
# seats                                                             5
# power                                                            87
# engine_size                                                       1
# co_emissions                                                     36
# drivetrain                                                    Front
# fuel_consumption                                                3.8
# comfort_convenience                                            High
# entertainment_media                                            High
# safety_security                                                High
# extras                                                       Medium
# general_inspection                                                0
# last_service                                                      0
# full_service_history                                              0
# non_smoker_vehicle                                                0
# emission_class                                                    6
# upholstery                                                    Cloth
# previous_owner                                                    0
# taxi_or_rental_car                                                0
# country                                                          ES
# age                                                             0.0
# comfort_convenience_n                                             3
# safety_security_n                                                 3
# entertainment_media_n                                             3
# extras_n                                                          2
#
#                                                                        2  \
# Unnamed: 0                                                             2
# make_model                                        Mercedes-Benz A 45 AMG
# make                                                       Mercedes-Benz
# location               PORT. TARRACO, MOLL DE LLEVANT, Nº 5, LOC. 6-8...
# price                                                              69900
# body_type                                                        Compact
# type                                                                Used
# doors                                                                  5
# warranty                                                               1
# mileage                                                          18900.0
# first_registration                                            2020-07-01
# gearbox                                                        Automatic
# fuel_type                                                        benzine
# colour                                                              Grey
# paint                                                              Basic
# seller                                                            Dealer
# seats                                                                  5
# power                                                                185
# engine_size                                                         1991
# co_emissions                                                         131
# drivetrain                                                           4WD
# fuel_consumption                                                     8.4
# comfort_convenience                                                  Low
# entertainment_media                                                  Low
# safety_security                                                      Low
# extras                                                               Low
# general_inspection                                                     0
# last_service                                                           0
# full_service_history                                                   0
# non_smoker_vehicle                                                     0
# emission_class                                                         6
# upholstery                                                         Cloth
# previous_owner                                                         0
# taxi_or_rental_car                                                     0
# country                                                               ES
# age                                                                  2.0
# comfort_convenience_n                                                  1
# safety_security_n                                                      1
# entertainment_media_n                                                  1
# extras_n                                                               1
#
#                                                                        3  \
# Unnamed: 0                                                             3
# make_model                                        Mercedes-Benz A 35 AMG
# make                                                       Mercedes-Benz
# location               Carrer de Provença, 31 Local,  8029 BARCELONA, ES
# price                                                              46990
# body_type                                                        Compact
# type                                                                Used
# doors                                                                  5
# warranty                                                               1
# mileage                                                          18995.0
# first_registration                                            2020-01-01
# gearbox                                                        Automatic
# fuel_type                                                        benzine
# colour                                                              Grey
# paint                                                              Basic
# seller                                                            Dealer
# seats                                                                  5
# power                                                                185
# engine_size                                                         1991
# co_emissions                                                         122
# drivetrain                                                           4WD
# fuel_consumption                                                     7.3
# comfort_convenience                                                  Low
# entertainment_media                                                  Low
# safety_security                                                      Low
# extras                                                               Low
# general_inspection                                                     0
# last_service                                                           0
# full_service_history                                                   0
# non_smoker_vehicle                                                     0
# emission_class                                                         6
# upholstery                                                         Cloth
# previous_owner                                                         0
# taxi_or_rental_car                                                     0
# country                                                               ES
# age                                                                  2.0
# comfort_convenience_n                                                  1
# safety_security_n                                                      1
# entertainment_media_n                                                  1
# extras_n                                                               1
#
#                                                             4
# Unnamed: 0                                                  4
# make_model                             Mercedes-Benz A 45 AMG
# make                                            Mercedes-Benz
# location               CARRIL ARAGONES 4,  30007 CASILLAS, ES
# price                                                   16800
# body_type                                             Compact
# type                                                     Used
# doors                                                       5
# warranty                                                    1
# mileage                                              197000.0
# first_registration                                 2015-09-01
# gearbox                                             Automatic
# fuel_type                                              diesel
# colour                                                   Grey
# paint                                                Metallic
# seller                                                 Dealer
# seats                                                       5
# power                                                     125
# engine_size                                              2143
# co_emissions                                              118
# drivetrain                                                4WD
# fuel_consumption                                          4.9
# comfort_convenience                                       Low
# entertainment_media                                       Low
# safety_security                                           Low
# extras                                                    Low
# general_inspection                                          0
# last_service                                                0
# full_service_history                                        0
# non_smoker_vehicle                                          0
# emission_class                                              6
# upholstery                                              Cloth
# previous_owner                                              0
# taxi_or_rental_car                                          0
# country                                                    ES
# age                                                       7.0
# comfort_convenience_n                                       1
# safety_security_n                                           1
# entertainment_media_n                                       1
# extras_n                                                    1

# %% [markdown]
# ## Getting a working copy

# %%
df=df0.copy()

# %% [markdown]
# ## Checking the columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'make_model', 'make', 'location', 'price', 'body_type',
#        'type', 'doors', 'warranty', 'mileage', 'first_registration', 'gearbox',
#        'fuel_type', 'colour', 'paint', 'seller', 'seats', 'power',
#        'engine_size', 'co_emissions', 'drivetrain', 'fuel_consumption',
#        'comfort_convenience', 'entertainment_media', 'safety_security',
#        'extras', 'general_inspection', 'last_service', 'full_service_history',
#        'non_smoker_vehicle', 'emission_class', 'upholstery', 'previous_owner',
#        'taxi_or_rental_car', 'country', 'age', 'comfort_convenience_n',
#        'safety_security_n', 'entertainment_media_n', 'extras_n'],
#       dtype='object')

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df.shape
# Out:
# (28630, 39)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28630 entries, 0 to 28629
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   make_model             28630 non-null  object
#  1   make                   28630 non-null  object
#  2   location               28630 non-null  object
#  3   price                  28630 non-null  int64
#  4   body_type              28630 non-null  object
#  5   type                   28630 non-null  object
#  6   doors                  28630 non-null  int64
#  7   warranty               28630 non-null  int64
#  8   mileage                28630 non-null  float64
#  9   first_registration     28628 non-null  object
#  10  gearbox                28630 non-null  object
#  11  fuel_type              28630 non-null  object
#  12  colour                 28630 non-null  object
#  13  paint                  28630 non-null  object
#  14  seller                 28630 non-null  object
#  15  seats                  28630 non-null  int64
#  16  power                  28630 non-null  int64
#  17  engine_size            28630 non-null  int64
#  18  co_emissions           28630 non-null  int64
#  19  drivetrain             28630 non-null  object
#  20  fuel_consumption       28630 non-null  float64
#  21  comfort_convenience    28630 non-null  object
#  22  entertainment_media    28630 non-null  object
#  23  safety_security        28630 non-null  object
#  24  extras                 28630 non-null  object
#  25  general_inspection     28630 non-null  int64
#  26  last_service           28630 non-null  int64
#  27  full_service_history   28630 non-null  int64
#  28  non_smoker_vehicle     28630 non-null  int64
#  29  emission_class         28630 non-null  int64
#  30  upholstery             28630 non-null  object
#  31  previous_owner         28630 non-null  int64
#  32  taxi_or_rental_car     28630 non-null  int64
#  33  country                28630 non-null  object
#  34  age                    28630 non-null  float64
#  35  comfort_convenience_n  28630 non-null  int64
#  36  safety_security_n      28630 non-null  int64
#  37  entertainment_media_n  28630 non-null  int64
#  38  extras_n               28630 non-null  int64
# dtypes: float64(3), int64(18), object(18)
# memory usage: 8.5+ MB

# %% [markdown]
# ## First registration

# %%
df["first_registration"] = pd.to_datetime(df["first_registration"])

# %%
df["first_registration"].dtype
# Out:
# dtype('<M8[ns]')

# %%
correlation = df['first_registration'].corr(df['age'])
print("Correlation coefficient between 'first_registration' and 'age':", correlation)
# Out:
# Correlation coefficient between 'first_registration' and 'age': -0.9494079834577595

# %% [markdown]
# ### There is a strong correlation between age and first_registration, so we can drop first_registration column.

# %%
df.drop('first_registration', axis=1, inplace=True)

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True, vmin = -1, vmax = 1);

# %% [markdown]
# ## Price

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x = df['price']);

# %%
np.log(df.price)
# Out:
# 0         9.738023
# 1        11.300969
# 2        11.154821
# 3        10.757690
# 4         9.729134
#            ...
# 28625    10.534759
# 28626     8.612322
# 28627     8.895630
# 28628    10.305614
# 28629     8.398410
# Name: price, Length: 28630, dtype: float64

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(x = np.log(df.price));

# %%
round(df['price'].describe(),2)
# Out:
# count      28630.00
# mean       23555.20
# std        25953.71
# min          490.00
# 25%        11990.00
# 50%        17980.00
# 75%        27990.00
# max      1346900.00
# Name: price, dtype: float64

# %%
Q1 = df.price.quantile(0.25)
Q3 = df.price.quantile(0.75)

IQR = Q3 - Q1
IQR
# Out:
# 16000.0

# %%
#lower_lim = Q1 - 2 * IQR
#upper_lim = Q3 + 2 * IQR  

#lower_lim, upper_lim

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR  

lower_lim, upper_lim
# Out:
# (-12010.0, 51990.0)

# %% [markdown]
# ### Average car price in Europe is around 50K.
# ### I reviewed 2 IQR and 1.5 IQR values and decided that 1.5 IQR is matching with the average car price in Europe.

# %%
no_outliers = (df['price'] <= upper_lim) & (df['price'] >= lower_lim)

# %%
df = df[no_outliers]

# %%
df.shape
# Out:
# (26720, 38)

# %%
df['type'].value_counts(dropna=False)
# Out:
# type
# Used              24013
# Pre-registered     1248
# Demonstration      1029
# Employee's car      430
# Name: count, dtype: int64

# %% [markdown]
# ## Doors

# %%
df['doors'].value_counts(dropna=False)
# Out:
# doors
# 5    16818
# 2     5079
# 4     2635
# 3     2181
# 6        5
# 1        2
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x="doors", hue=df['doors'].astype(str));     # matplotlib requires labels (x axis) to be str

# %%
df.loc[df['doors']==1]
# Out:
#             make_model  make  \
# 10001  Fiat 124 Spider  Fiat
# 21140      Ford Fiesta  Ford
#
#                                                 location  price    body_type  \
# 10001  Via Chisini, 154,  31053 Pieve Di Soligo - Tre...  19000  Convertible
# 21140              Ossiacher Zeile 29,  9500 Villach, AT  11790      Compact
#
#        type  doors  warranty  mileage gearbox  ... emission_class upholstery  \
# 10001  Used      1         0  48500.0  Manual  ...              6    Leather
# 21140  Used      1         3  14600.0  Manual  ...              6      Cloth
#
#       previous_owner taxi_or_rental_car  country   age  comfort_convenience_n  \
# 10001              0                  0       IT  55.0                      2
# 21140              1                  0       AT   5.0                      1
#
#        safety_security_n entertainment_media_n  extras_n
# 10001                  2                     2         1
# 21140                  2                     1         1
#
# [2 rows x 38 columns]

# %%
df.loc[10001, 'doors'] = 2 # fiat 124 Spider 2 kapili oldugu icin

# %%
df.loc[10001, 'doors']
# Out:
# 2

# %%
df.loc[21140, 'doors'] = 5 #  Ford Fiesta Compact 5 kapili oldugu icin

# %%
df.loc[21140, 'doors']
# Out:
# 5

# %%
df.loc[df['doors']==6]
# Out:
#          make_model   make                                           location  \
# 15931   Dacia Logan  Dacia        Chaussée de Louvain 721,  5020 Champion, BE
# 16097   Dacia Logan  Dacia                SOMBREFFE 5140,  5140 SOMBREFFE, BE
# 16105  Dacia Dokker  Dacia  Ninoofsesteenweg 839,  1703 Dilbeek - Schepdaa...
# 16129   Dacia Logan  Dacia                                 7390 Quaregnon, BE
# 16163   Dacia Logan  Dacia  Rue du Petit Chêne 21,  4000 Liege Coronmeuse, BE
#
#        price      body_type  type  doors  warranty   mileage gearbox  ...  \
# 15931   2700  Station wagon  Used      6         0  210877.0  Manual  ...
# 16097   1700  Station wagon  Used      6         0  144043.0  Manual  ...
# 16105  16900  Station wagon  Used      6         2      90.0  Manual  ...
# 16129   3000  Station wagon  Used      6         0  258000.0  Manual  ...
# 16163   5950  Station wagon  Used      6         0  173000.0  Manual  ...
#
#       emission_class upholstery previous_owner taxi_or_rental_car  country  \
# 15931              6      Cloth              1                  0       BE
# 16097              6      Cloth              0                  0       BE
# 16105              6      Cloth              0                  0       BE
# 16129              6      Cloth              1                  0       BE
# 16163              6      Cloth              1                  0       BE
#
#         age  comfort_convenience_n  safety_security_n entertainment_media_n  \
# 15931  12.0                      1                  1                     1
# 16097  14.0                      1                  1                     1
# 16105   0.0                      1                  1                     2
# 16129  12.0                      1                  1                     1
# 16163  10.0                      1                  1                     1
#
#        extras_n
# 15931         1
# 16097         2
# 16105         1
# 16129         1
# 16163         1
#
# [5 rows x 38 columns]

# %%
df.loc[[15931,16097,16105,16129,16163], 'doors']=5

# %%
df.loc[[15931,16097,16105,16129,16163]]
# Out:
#          make_model   make                                           location  \
# 15931   Dacia Logan  Dacia        Chaussée de Louvain 721,  5020 Champion, BE
# 16097   Dacia Logan  Dacia                SOMBREFFE 5140,  5140 SOMBREFFE, BE
# 16105  Dacia Dokker  Dacia  Ninoofsesteenweg 839,  1703 Dilbeek - Schepdaa...
# 16129   Dacia Logan  Dacia                                 7390 Quaregnon, BE
# 16163   Dacia Logan  Dacia  Rue du Petit Chêne 21,  4000 Liege Coronmeuse, BE
#
#        price      body_type  type  doors  warranty   mileage gearbox  ...  \
# 15931   2700  Station wagon  Used      5         0  210877.0  Manual  ...
# 16097   1700  Station wagon  Used      5         0  144043.0  Manual  ...
# 16105  16900  Station wagon  Used      5         2      90.0  Manual  ...
# 16129   3000  Station wagon  Used      5         0  258000.0  Manual  ...
# 16163   5950  Station wagon  Used      5         0  173000.0  Manual  ...
#
#       emission_class upholstery previous_owner taxi_or_rental_car  country  \
# 15931              6      Cloth              1                  0       BE
# 16097              6      Cloth              0                  0       BE
# 16105              6      Cloth              0                  0       BE
# 16129              6      Cloth              1                  0       BE
# 16163              6      Cloth              1                  0       BE
#
#         age  comfort_convenience_n  safety_security_n entertainment_media_n  \
# 15931  12.0                      1                  1                     1
# 16097  14.0                      1                  1                     1
# 16105   0.0                      1                  1                     2
# 16129  12.0                      1                  1                     1
# 16163  10.0                      1                  1                     1
#
#        extras_n
# 15931         1
# 16097         2
# 16105         1
# 16129         1
# 16163         1
#
# [5 rows x 38 columns]

# %% [markdown]
# ## Mileage

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x = df['mileage']);

# %%
round(df['mileage'].describe(),2)
# Out:
# count      26720.00
# mean       75904.09
# std        67995.83
# min            0.00
# 25%        23795.25
# 50%        61372.00
# 75%       110458.75
# max      1440000.00
# Name: mileage, dtype: float64

# %%
Q1 = df.mileage.quantile(0.25)
Q3 = df.mileage.quantile(0.75)

IQR = Q3 - Q1
IQR
# Out:
# 86663.5

# %%
#lower_lim = Q1 - 1.5 * IQR
#upper_lim = Q3 + 1.5 * IQR  

#lower_lim, upper_lim

# %%
lower_lim = Q1 - 2 * IQR
upper_lim = Q3 + 2 * IQR  

lower_lim, upper_lim
# Out:
# (-149531.75, 283785.75)

# %%
no_outliers= (df['mileage'] <= upper_lim) & (df['mileage'] >= lower_lim)

# %%
df = df[no_outliers]

# %%
df.shape
# Out:
# (26478, 38)

# %% [markdown]
# ## Power

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x = df['power']);

# %%
round(df['power'].describe(),2)
# Out:
# count    26478.00
# mean       108.13
# std         45.99
# min         13.00
# 25%         81.00
# 50%         96.00
# 75%        125.00
# max        527.00
# Name: power, dtype: float64

# %%
Q1 = df.power.quantile(0.25)
Q3 = df.power.quantile(0.75)

IQR = Q3 - Q1
IQR
# Out:
# 44.0

# %%
lower_lim = Q1 - IQR
upper_lim = Q3 + IQR  

lower_lim, upper_lim
# Out:
# (37.0, 169.0)

# %%
lower_lim3 = Q1 - 3 * IQR
upper_lim3= Q3 + 3 * IQR  

lower_lim3, upper_lim3
# Out:
# (-51.0, 257.0)

# %%
no_outliers= (df['power'] <= upper_lim3) & (df['power'] >= lower_lim)

# %%
df = df[no_outliers]

# %%
df.shape
# Out:
# (26003, 38)

# %% [markdown]
# ## Engine Size

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x = df['engine_size']);

# %%
round(df['engine_size'].describe(),2)
# Out:
# count    26003.00
# mean      1619.63
# std        845.74
# min          0.00
# 25%       1242.00
# 50%       1580.00
# 75%       1969.00
# max      99900.00
# Name: engine_size, dtype: float64

# %%
df.loc[df['engine_size']>20000][['make_model','engine_size']]
# Out:
#           make_model  engine_size
# 16556  Dacia Sandero        99900

# %%
df.drop(16556, inplace=True)

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x = df['engine_size']);

# %%
Q1 = df.engine_size.quantile(0.25)
Q3 = df.engine_size.quantile(0.75)

IQR = Q3 - Q1
IQR
# Out:
# 727.0

# %%
round(df['engine_size'].describe(),2)
# Out:
# count    26002.00
# mean      1615.85
# std        586.34
# min          0.00
# 25%       1242.00
# 50%       1580.00
# 75%       1969.00
# max      19194.00
# Name: engine_size, dtype: float64

# %%
lower_lim = Q1 - 1.5*IQR
upper_lim = Q3 + 3*IQR  

lower_lim, upper_lim
# Out:
# (151.5, 4150.0)

# %%
no_outliers= (df['engine_size'] <= upper_lim) & (df['engine_size'] >= lower_lim)

# %%
df = df[no_outliers]

# %%
df.shape
# Out:
# (25580, 38)

# %% [markdown]
# ## Age

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x = df['age']);

# %%
round(df['age'].describe(),2)
# Out:
# count    25580.00
# mean         6.68
# std          7.75
# min       -180.00
# 25%          2.00
# 50%          4.00
# 75%          8.00
# max        122.00
# Name: age, dtype: float64

# %%
df.loc[df['age']<0]
# Out:
#             make_model     make                                     location  \
# 7011      Renault Clio  Renault                              59223 Roncq, FR
# 9764   Fiat 500 Abarth     Fiat      Lange Dreef 29,  3902 AE VEENENDAAL, NL
# 19213     Nissan Micra   Nissan  Geelhoornstraat 9a,  2172 BC SASSENHEIM, NL
#
#        price    body_type  type  doors  warranty   mileage gearbox  ...  \
# 7011   16990        Sedan  Used      5         0   20926.0  Manual  ...
# 9764   17995      Compact  Used      3         0   59629.0  Manual  ...
# 19213   3250  Convertible  Used      2         0  147985.0  Manual  ...
#
#       emission_class upholstery previous_owner taxi_or_rental_car  country  \
# 7011               5      Cloth              0                  0       FR
# 9764               6      Cloth              0                  0       NL
# 19213              6    Leather              0                  0       NL
#
#          age  comfort_convenience_n  safety_security_n entertainment_media_n  \
# 7011  -180.0                      2                  2                     1
# 9764    -3.0                      1                  2                     1
# 19213   -1.0                      1                  1                     1
#
#        extras_n
# 7011          1
# 9764          1
# 19213         1
#
# [3 rows x 38 columns]

# %%
df.drop([7011,9764, 19213], inplace=True)

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x = df['age']);

# %%
Q1 = df.age.quantile(0.25)
Q3 = df.age.quantile(0.75)

IQR = Q3 - Q1
IQR
# Out:
# 6.0

# %%
lower_lim = Q1 - 1.5*IQR
upper_lim = Q3 + 4*IQR  

lower_lim, upper_lim
# Out:
# (-7.0, 32.0)

# %%
df.loc[df['age']>32][['make_model','price', 'age']]
# Out:
#                  make_model  price   age
# 88      Mercedes-Benz E 300   4500  36.0
# 538    Mercedes-Benz SL 300  32500  35.0
# 556    Mercedes-Benz SL 280  33890  43.0
# 578    Mercedes-Benz SL 380  28490  39.0
# 634    Mercedes-Benz SL 300  49890  34.0
# ...                     ...    ...   ...
# 26715             Volvo 480   5400  35.0
# 27802           Volvo P1800  25000  49.0
# 28182           Volvo P1800  25000  49.0
# 28496             Volvo 244   7450  43.0
# 28504             Volvo 240   9850  36.0
#
# [368 rows x 3 columns]

# %%
no_outliers= (df['age'] <= upper_lim) & (df['age'] >= lower_lim)

# %%
df = df[no_outliers]

# %%
df.shape
# Out:
# (25209, 38)

# %% [markdown]
# ## Co Emission

# %%
plt.figure(figsize=(15, 8))
sns.boxplot(x = df['co_emissions']);

# %%
round(df.co_emissions.describe(),2)
# Out:
# count    25209.00
# mean       136.11
# std         57.90
# min          0.00
# 25%        109.00
# 50%        129.00
# 75%        162.00
# max        414.00
# Name: co_emissions, dtype: float64

# %%
Q1 = df.co_emissions.quantile(0.25)
Q3 = df.co_emissions.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 53.0

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 2.5 * IQR
lower_lim, upper_lim
# Out:
# (29.5, 294.5)

# %%
no_outliers= (df['co_emissions'] <= upper_lim) & (df['co_emissions'] >= lower_lim)

# %%
df = df[no_outliers]

# %%
df.shape
# Out:
# (23719, 38)

# %% [markdown]
# ## Fuel consumption

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x = df['fuel_consumption']);

# %%
df.loc[df['fuel_consumption']>20][['make_model', 'fuel_consumption']]
# Out:
#                 make_model  fuel_consumption
# 265    Mercedes-Benz A 180              99.9
# 1771   Mercedes-Benz E 200              61.0
# 6580        Renault Megane              57.0
# 18546         Toyota Yaris              56.0
# 18757       Nissan Qashqai              99.9
# 18760       Nissan Qashqai              99.9
# 18798       Nissan Qashqai              99.9
# 18799       Nissan Qashqai              99.9
# 19904       Nissan Qashqai              44.0
# 20995           Ford Focus              93.0
# 21012           Ford Focus              93.0
# 22992           Ford Focus              99.9
# 23004           Ford Focus              99.9
# 23974         Hyundai KONA              53.0
# 24144         Hyundai KONA              53.0

# %%
df.drop(df.loc[df['fuel_consumption']>20].index,inplace=True)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x = df['fuel_consumption']);

# %%
round(df['fuel_consumption'].describe(),2)
# Out:
# count    23704.00
# mean         5.45
# std          2.00
# min          0.00
# 25%          4.30
# 50%          5.20
# 75%          6.40
# max         16.00
# Name: fuel_consumption, dtype: float64

# %%
Q1 = df.fuel_consumption.quantile(0.25)
Q3 = df.fuel_consumption.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 2.1000000000000005

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 2 * IQR
lower_lim, upper_lim
# Out:
# (1.149999999999999, 10.600000000000001)

# %%
no_outliers= (df['fuel_consumption'] <= upper_lim) & (df['fuel_consumption'] >= lower_lim)

# %%
df = df[no_outliers]

# %%
df.shape
# Out:
# (22588, 38)

# %%
df.head().T
# Out:
#                                                                        0  \
# make_model                                           Mercedes-Benz A 160
# make                                                       Mercedes-Benz
# location               P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# price                                                              16950
# body_type                                                        Compact
# type                                                                Used
# doors                                                                  5
# warranty                                                               2
# mileage                                                         120200.0
# gearbox                                                           Manual
# fuel_type                                                         diesel
# colour                                                              Grey
# paint                                                           Metallic
# seller                                                            Dealer
# seats                                                                  5
# power                                                                 81
# engine_size                                                         1461
# co_emissions                                                         131
# drivetrain                                                         Front
# fuel_consumption                                                     3.8
# comfort_convenience                                                  Low
# entertainment_media                                                  Low
# safety_security                                                   Medium
# extras                                                               Low
# general_inspection                                                     0
# last_service                                                           0
# full_service_history                                                   0
# non_smoker_vehicle                                                     0
# emission_class                                                         6
# upholstery                                                         Cloth
# previous_owner                                                         0
# taxi_or_rental_car                                                     0
# country                                                               ES
# age                                                                  6.0
# comfort_convenience_n                                                  1
# safety_security_n                                                      2
# entertainment_media_n                                                  1
# extras_n                                                               1
#
#                                                                        3  \
# make_model                                        Mercedes-Benz A 35 AMG
# make                                                       Mercedes-Benz
# location               Carrer de Provença, 31 Local,  8029 BARCELONA, ES
# price                                                              46990
# body_type                                                        Compact
# type                                                                Used
# doors                                                                  5
# warranty                                                               1
# mileage                                                          18995.0
# gearbox                                                        Automatic
# fuel_type                                                        benzine
# colour                                                              Grey
# paint                                                              Basic
# seller                                                            Dealer
# seats                                                                  5
# power                                                                185
# engine_size                                                         1991
# co_emissions                                                         122
# drivetrain                                                           4WD
# fuel_consumption                                                     7.3
# comfort_convenience                                                  Low
# entertainment_media                                                  Low
# safety_security                                                      Low
# extras                                                               Low
# general_inspection                                                     0
# last_service                                                           0
# full_service_history                                                   0
# non_smoker_vehicle                                                     0
# emission_class                                                         6
# upholstery                                                         Cloth
# previous_owner                                                         0
# taxi_or_rental_car                                                     0
# country                                                               ES
# age                                                                  2.0
# comfort_convenience_n                                                  1
# safety_security_n                                                      1
# entertainment_media_n                                                  1
# extras_n                                                               1
#
#                                                             4  \
# make_model                             Mercedes-Benz A 45 AMG
# make                                            Mercedes-Benz
# location               CARRIL ARAGONES 4,  30007 CASILLAS, ES
# price                                                   16800
# body_type                                             Compact
# type                                                     Used
# doors                                                       5
# warranty                                                    1
# mileage                                              197000.0
# gearbox                                             Automatic
# fuel_type                                              diesel
# colour                                                   Grey
# paint                                                Metallic
# seller                                                 Dealer
# seats                                                       5
# power                                                     125
# engine_size                                              2143
# co_emissions                                              118
# drivetrain                                                4WD
# fuel_consumption                                          4.9
# comfort_convenience                                       Low
# entertainment_media                                       Low
# safety_security                                           Low
# extras                                                    Low
# general_inspection                                          0
# last_service                                                0
# full_service_history                                        0
# non_smoker_vehicle                                          0
# emission_class                                              6
# upholstery                                              Cloth
# previous_owner                                              0
# taxi_or_rental_car                                          0
# country                                                    ES
# age                                                       7.0
# comfort_convenience_n                                       1
# safety_security_n                                           1
# entertainment_media_n                                       1
# extras_n                                                    1
#
#                                                            5  \
# make_model                               Mercedes-Benz C 160
# make                                           Mercedes-Benz
# location               Beethovenstr. 89,  42655 Solingen, DE
# price                                                   4690
# body_type                                            Compact
# type                                                    Used
# doors                                                      3
# warranty                                                   0
# mileage                                             165000.0
# gearbox                                               Manual
# fuel_type                                            benzine
# colour                                                  Grey
# paint                                               Metallic
# seller                                                Dealer
# seats                                                      4
# power                                                     90
# engine_size                                             1799
# co_emissions                                              95
# drivetrain                                              Rear
# fuel_consumption                                         8.2
# comfort_convenience                                   Medium
# entertainment_media                                      Low
# safety_security                                       Medium
# extras                                                Medium
# general_inspection                                         1
# last_service                                               1
# full_service_history                                       1
# non_smoker_vehicle                                         1
# emission_class                                             6
# upholstery                                             Cloth
# previous_owner                                             0
# taxi_or_rental_car                                         0
# country                                                   DE
# age                                                     17.0
# comfort_convenience_n                                      2
# safety_security_n                                          2
# entertainment_media_n                                      1
# extras_n                                                   2
#
#                                                                      6
# make_model                                       Mercedes-Benz CLA 180
# make                                                     Mercedes-Benz
# location               CR PATERNA-LA CAÑADA, KM. 2,  46980 PATERNA, ES
# price                                                            22550
# body_type                                                      Compact
# type                                                              Used
# doors                                                                5
# warranty                                                             1
# mileage                                                        83339.0
# gearbox                                                         Manual
# fuel_type                                                       diesel
# colour                                                            Grey
# paint                                                            Basic
# seller                                                          Dealer
# seats                                                                5
# power                                                               90
# engine_size                                                       1595
# co_emissions                                                        95
# drivetrain                                                        Rear
# fuel_consumption                                                   8.2
# comfort_convenience                                             Medium
# entertainment_media                                                Low
# safety_security                                                 Medium
# extras                                                          Medium
# general_inspection                                                   0
# last_service                                                         0
# full_service_history                                                 0
# non_smoker_vehicle                                                   0
# emission_class                                                       6
# upholstery                                                       Cloth
# previous_owner                                                       0
# taxi_or_rental_car                                                   0
# country                                                             ES
# age                                                                4.0
# comfort_convenience_n                                                2
# safety_security_n                                                    2
# entertainment_media_n                                                1
# extras_n                                                             2

# %% [markdown]
# ## Checking the final situation of the data via graphs

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(numeric_only=True), annot=True, vmin = -1, vmax = 1, cmap='coolwarm');

# %%
sns.boxplot(data = df, x = "gearbox", y = "price", hue='gearbox'); #bu bize gearbox in price i etkiledigini gösterir.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "body_type", y = "price", hue='body_type');

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "type", y = "price", hue='type');

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "doors", y = "price", hue='doors');

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "warranty", y = "price", hue='warranty');

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "fuel_type", y = "price", hue='fuel_type');

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "colour", y = "price", hue='colour');

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "paint", y = "price", hue='paint');

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "seller", y = "price", hue='seller');

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "seats", y = "price", hue='seats');

# %% [markdown]
# ## Seats

# %%
df.loc[df['seats']==0]
# Out:
#            make_model     make  \
# 4866   Renault Twingo  Renault
# 11962      SEAT Ibiza     SEAT
# 12073      SEAT Ibiza     SEAT
# 13472     SEAT Toledo     SEAT
# 13520      SEAT Ibiza     SEAT
# 14979     Skoda Fabia    Skoda
# 15105     Skoda Fabia    Skoda
# 24303     Hyundai i30  Hyundai
#
#                                                 location  price  \
# 4866   Alte Plauener Str. 2,  08541 Neuensalz bei Pla...   7750
# 11962  Neue Straße 53,  38444 Wolfsburg Heiligendorf, DE   9900
# 12073  Neue Straße 53,  38444 Wolfsburg Heiligendorf, DE  14700
# 13472  Neue Straße 53,  38444 Wolfsburg Heiligendorf, DE   7650
# 13520        Berliner Eck,  23758 Oldenburg/Holstein, DE  18950
# 14979  Neue Straße 53,  38444 Wolfsburg Heiligendorf, DE   2900
# 15105  Neue Straße 53,  38444 Wolfsburg Heiligendorf, DE   2950
# 24303  Neue Straße 53,  38444 Wolfsburg Heiligendorf, DE   8900
#
#            body_type  type  doors  warranty   mileage gearbox  ...  \
# 4866         Compact  Used      5         0   53335.0  Manual  ...
# 11962        Compact  Used      5         0  132390.0  Manual  ...
# 12073        Compact  Used      5         0   66510.0  Manual  ...
# 13472          Sedan  Used      5         0  124800.0  Manual  ...
# 13520          Sedan  Used      4         1   11400.0  Manual  ...
# 14979          Sedan  Used      5         0  197000.0  Manual  ...
# 15105          Sedan  Used      5         0  139877.0  Manual  ...
# 24303  Station wagon  Used      5         0  114730.0  Manual  ...
#
#       emission_class upholstery previous_owner taxi_or_rental_car  country  \
# 4866               6      Cloth              1                  0       DE
# 11962              6      Cloth              1                  0       DE
# 12073              6      Cloth              0                  0       DE
# 13472              6      Cloth              1                  0       DE
# 13520              5      Cloth              1                  0       DE
# 14979              6      Cloth              1                  0       DE
# 15105              6      Cloth              1                  0       DE
# 24303              6      Cloth              0                  0       DE
#
#         age  comfort_convenience_n  safety_security_n entertainment_media_n  \
# 4866    7.0                      1                  2                     2
# 11962   7.0                      2                  2                     1
# 12073   4.0                      1                  2                     1
# 13472   8.0                      1                  2                     2
# 13520   2.0                      2                  2                     2
# 14979  13.0                      1                  1                     1
# 15105  14.0                      1                  1                     1
# 24303   8.0                      1                  2                     2
#
#        extras_n
# 4866          1
# 11962         1
# 12073         1
# 13472         1
# 13520         2
# 14979         1
# 15105         1
# 24303         1
#
# [8 rows x 38 columns]

# %%
df.loc[[4866,11962, 12073, 13520, 14979,15105], 'seats']=4

# %%
df.loc[[13472, 24303], 'seats']=5

# %%
df.loc[df['seats']==9]
# Out:
#                 make_model           make  \
# 497    Mercedes-Benz C 250  Mercedes-Benz
# 4004           Opel Vivaro           Opel
# 4023           Opel Vivaro           Opel
# 4063           Opel Vivaro           Opel
# 4181           Opel Vivaro           Opel
# 4355           Opel Vivaro           Opel
# 6362        Renault Trafic        Renault
# 6393        Renault Trafic        Renault
# 6400        Renault Trafic        Renault
# 6418        Renault Trafic        Renault
# 6421        Renault Trafic        Renault
# 11090         Fiat Talento           Fiat
# 18075        Toyota Proace         Toyota
# 18219        Toyota Proace         Toyota
# 20021         Nissan NV300         Nissan
# 20035     Nissan Primastar         Nissan
# 20037         Nissan NV300         Nissan
# 20038     Nissan Primastar         Nissan
# 20044         Nissan NV300         Nissan
# 20086     Nissan Primastar         Nissan
# 20105         Nissan NV300         Nissan
# 20122     Nissan Primastar         Nissan
# 20195         Nissan NV300         Nissan
# 20244         Nissan NV300         Nissan
# 20279     Nissan Primastar         Nissan
# 22335  Ford Tourneo Custom           Ford
# 22336  Ford Tourneo Custom           Ford
# 22337  Ford Transit Custom           Ford
# 22376  Ford Tourneo Custom           Ford
# 22430  Ford Tourneo Custom           Ford
# 22537  Ford Tourneo Custom           Ford
# 22713  Ford Tourneo Custom           Ford
#
#                                                 location  price  \
# 497            Von Guericke Str. 4,  38350 Helmstedt, DE  34970
# 4004           Am Flughafen 1/3/5,  12529 Schönefeld, DE  29880
# 4023            Wölsauer Str. 6,  95615 Marktredwitz, DE  27870
# 4063         Siegfried-Marcus-Straße 1,  17192 Waren, DE  47500
# 4181                    Moselstraße 11,  41464 Neuss, DE  44740
# 4355   Torfbruchstraße 329a,  40625 Düsseldorf-Gerres...  32990
# 6362            Benzstraße 2 + 23,  93053 Regensburg, DE  30900
# 6393      Lindenstraße 54,  15517 Fürstenwalde/Spree, DE  33890
# 6400            Benzstraße 2 + 23,  93053 Regensburg, DE  30900
# 6418                Seeburger Str. 68,  13581 Berlin, DE  34890
# 6421                Seeburger Str. 68,  13581 Berlin, DE  34890
# 11090              Gewerbestr. 20,  86720 Nördlingen, DE  29990
# 18075            Weimarische Str. 140,  99098 Erfurt, DE  39950
# 18219             Erlenweg 1-2,  94104 Witzmannsberg, DE  39900
# 20021  Gärtnerstraße 17-18,  13055 Berlin / Hohenschö...  25300
# 20035           Marie-Curie-Ring 25,  55291 Saulheim, DE   7299
# 20037  Recklinghäuser Str. 122,  45721 Haltern am See...  36990
# 20038              Gewerbestr. 20,  86720 Nördlingen, DE  42995
# 20044                  Siemensstr. 2,  40789 Monheim, DE  33770
# 20086      Ernst-Thälmann-Straße 37,  01809 Heidenau, DE  19990
# 20105                                  6820 Frastanz, AT  24580
# 20122                    08173 Sant Cugat Del Valles, ES  10150
# 20195                 Eitzer Str. 217,  27283 Verden, DE  35900
# 20244             Gahlenfeldstr. 39,  58313 Herdecke, DE  38990
# 20279            In der Au 2,  88515 Langenenslingen, DE  44900
# 22335     Martin-Luther-Str. 37,  15517 Fürstenwalde, DE  39970
# 22336               Buschkrugallee 43,  12359 Berlin, DE  41980
# 22337             Hamburger Str. 10,  41540 Dormagen, DE  34800
# 22376     Martin-Luther-Str. 37,  15517 Fürstenwalde, DE  40470
# 22430     Martin-Luther-Str. 37,  15517 Fürstenwalde, DE  35470
# 22537     Martin-Luther-Str. 37,  15517 Fürstenwalde, DE  34970
# 22713     Martin-Luther-Str. 37,  15517 Fürstenwalde, DE  40470
#
#            body_type            type  doors  warranty   mileage    gearbox  \
# 497      Convertible            Used      2         0   85002.0  Automatic
# 4004   Station wagon            Used      4         0   31903.0     Manual
# 4023   Station wagon            Used      4         0   70994.0     Manual
# 4063   Station wagon            Used      4         1   18877.0     Manual
# 4181   Station wagon            Used      5         0     150.0     Manual
# 4355   Station wagon   Demonstration      4         0   46700.0     Manual
# 6362   Station wagon            Used      4         0   42400.0     Manual
# 6393   Station wagon            Used      4         0   27301.0     Manual
# 6400   Station wagon            Used      4         0   46200.0     Manual
# 6418   Station wagon            Used      4         0   18086.0     Manual
# 6421   Station wagon            Used      4         0   21981.0     Manual
# 11090  Station wagon            Used      4         0   31370.0     Manual
# 18075  Station wagon   Demonstration      4         2    5000.0     Manual
# 18219  Station wagon   Demonstration      4         0    1000.0     Manual
# 20021  Station wagon            Used      5         0   85443.0     Manual
# 20035  Station wagon            Used      4         0  204880.0     Manual
# 20037  Station wagon            Used      4         0   14750.0     Manual
# 20038  Station wagon  Pre-registered      5         0      50.0  Automatic
# 20044  Station wagon            Used      5         0   15406.0     Manual
# 20086  Station wagon            Used      4         0  174000.0     Manual
# 20105  Station wagon            Used      5         0   93841.0     Manual
# 20122  Station wagon            Used      4         0  250000.0     Manual
# 20195  Station wagon            Used      5         0   23860.0     Manual
# 20244  Station wagon            Used      4         0    9980.0  Automatic
# 20279  Station wagon   Demonstration      4         0   10000.0  Automatic
# 22335  Station wagon            Used      4         0   40303.0     Manual
# 22336  Station wagon            Used      4         3   16709.0     Manual
# 22337  Station wagon            Used      4         1   91263.0  Automatic
# 22376  Station wagon            Used      4         0   18870.0     Manual
# 22430  Station wagon            Used      4         0   77950.0     Manual
# 22537  Station wagon            Used      4         0   21985.0     Manual
# 22713  Station wagon            Used      4         0   19800.0     Manual
#
#        ... emission_class upholstery previous_owner taxi_or_rental_car  \
# 497    ...              6    Leather              1                  0
# 4004   ...              6      Other              1                  0
# 4023   ...              6      Cloth              1                  0
# 4063   ...              6      Cloth              1                  0
# 4181   ...              5      Cloth              1                  0
# 4355   ...              6      Cloth              1                  0
# 6362   ...              6      Cloth              1                  0
# 6393   ...              6      Cloth              1                  0
# 6400   ...              6      Cloth              1                  0
# 6418   ...              6      Cloth              1                  0
# 6421   ...              6      Cloth              1                  0
# 11090  ...              6      Cloth              0                  0
# 18075  ...              6      Cloth              1                  0
# 18219  ...              2      Cloth              1                  0
# 20021  ...              6      Cloth              1                  0
# 20035  ...              6      Cloth              1                  0
# 20037  ...              6      Cloth              1                  0
# 20038  ...              6      Cloth              1                  0
# 20044  ...              6      Cloth              1                  1
# 20086  ...              4      Other              1                  0
# 20105  ...              6      Cloth              1                  0
# 20122  ...              6      Cloth              0                  0
# 20195  ...              6      Cloth              1                  0
# 20244  ...              6      Cloth              1                  0
# 20279  ...              6      Cloth              1                  0
# 22335  ...              6    Leather              1                  0
# 22336  ...              6      Cloth              1                  0
# 22337  ...              5      Other              1                  0
# 22376  ...              4      Other              1                  0
# 22430  ...              4      Other              1                  0
# 22537  ...              4      Other              1                  0
# 22713  ...              6      Other              0                  0
#
#        country   age  comfort_convenience_n  safety_security_n  \
# 497         DE   5.0                      2                  3
# 4004        DE   6.0                      2                  2
# 4023        DE   6.0                      1                  2
# 4063        DE   4.0                      2                  2
# 4181        DE   0.0                      1                  1
# 4355        DE   1.0                      2                  2
# 6362        DE   2.0                      1                  2
# 6393        DE   2.0                      1                  2
# 6400        DE   2.0                      1                  1
# 6418        DE   2.0                      1                  2
# 6421        DE   2.0                      1                  2
# 11090       DE   5.0                      1                  1
# 18075       DE   0.0                      2                  2
# 18219       DE   0.0                      1                  2
# 20021       DE   5.0                      2                  1
# 20035       DE  19.0                      1                  1
# 20037       DE   2.0                      1                  1
# 20038       DE   0.0                      2                  2
# 20044       DE   1.0                      1                  1
# 20086       DE   8.0                      2                  2
# 20105       AT   5.0                      2                  1
# 20122       ES  12.0                      2                  2
# 20195       DE   2.0                      1                  2
# 20244       DE   2.0                      2                  2
# 20279       DE   0.0                      2                  2
# 22335       DE   3.0                      2                  2
# 22336       DE   1.0                      2                  2
# 22337       DE   5.0                      2                  2
# 22376       DE   3.0                      2                  2
# 22430       DE   3.0                      2                  2
# 22537       DE   3.0                      2                  2
# 22713       DE   3.0                      2                  2
#
#       entertainment_media_n  extras_n
# 497                       2         2
# 4004                      2         1
# 4023                      1         1
# 4063                      1         2
# 4181                      2         1
# 4355                      2         1
# 6362                      1         2
# 6393                      2         1
# 6400                      2         2
# 6418                      2         1
# 6421                      2         1
# 11090                     1         1
# 18075                     3         2
# 18219                     2         1
# 20021                     2         1
# 20035                     1         1
# 20037                     1         1
# 20038                     1         1
# 20044                     2         1
# 20086                     2         1
# 20105                     1         1
# 20122                     2         1
# 20195                     1         1
# 20244                     2         1
# 20279                     2         1
# 22335                     3         2
# 22336                     2         2
# 22337                     2         1
# 22376                     3         1
# 22430                     2         2
# 22537                     2         1
# 22713                     3         2
#
# [32 rows x 38 columns]

# %%
df.loc[df['seats']==1]
# Out:
#          make_model     make  \
# 5173       Renault   Renault
# 5816  Renault Twizy  Renault
# 6205  Renault Twizy  Renault
# 7559    Peugeot 308  Peugeot
#
#                                                location  price  \
# 5173  Via dell'Artigianato, 14/16,  35020 Albignaseg...   6500
# 5816                                  22081 Hamburg, DE   3999
# 6205            De Hoogt 12b,  5175 AX LOON OP ZAND, NL   7950
# 7559       17 rue de l'église,  57790 Koenigsmacker, FR  10750
#
#              body_type  type  doors  warranty  mileage    gearbox  ...  \
# 5173           Compact  Used      2         0  21400.0  Automatic  ...
# 5816             Coupe  Used      2         0  91900.0  Automatic  ...
# 6205  Off-Road/Pick-up  Used      2         1  35784.0  Automatic  ...
# 7559       Convertible  Used      2         1  82000.0     Manual  ...
#
#      emission_class upholstery previous_owner taxi_or_rental_car  country  \
# 5173              6      Other              1                  0       IT
# 5816              6      Cloth              1                  0       DE
# 6205              6      Cloth              1                  0       NL
# 7559              6    Leather              1                  0       FR
#
#        age  comfort_convenience_n  safety_security_n entertainment_media_n  \
# 5173   4.0                      1                  1                     1
# 5816   7.0                      1                  1                     1
# 6205   6.0                      1                  2                     2
# 7559  12.0                      2                  2                     2
#
#       extras_n
# 5173         1
# 5816         1
# 6205         1
# 7559         1
#
# [4 rows x 38 columns]

# %%
df.loc[[5816, 6205,5173], 'seats']=2

# %%
df.loc[[7559], 'seats']=5

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "seats", y = "price", hue='seats');

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "drivetrain", y = "price", hue='drivetrain');

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "general_inspection", y = "price", hue='general_inspection');

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "upholstery", y = "price", hue='upholstery');

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "country", y = "price", hue='country');

# %%
df['make'].value_counts(dropna=False)
# Out:
# make
# Volvo            2953
# Peugeot          2136
# Opel             2051
# Renault          1983
# Fiat             1890
# Hyundai          1644
# SEAT             1571
# Toyota           1552
# Ford             1478
# Nissan           1398
# Dacia            1358
# Skoda            1348
# Mercedes-Benz    1226
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = df, x = "make", y = "price", hue='make');

# %% [markdown]
# ## Dropping unnecessary columns

# %%
df.drop(['colour', 'safety_security','safety_security_n','entertainment_media_n', 'entertainment_media', 'extras', 'extras_n', 'general_inspection', 'emission_class', 'country', 'comfort_convenience_n' ], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22588 entries, 0 to 28629
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   make_model            22588 non-null  object
#  1   make                  22588 non-null  object
#  2   location              22588 non-null  object
#  3   price                 22588 non-null  int64
#  4   body_type             22588 non-null  object
#  5   type                  22588 non-null  object
#  6   doors                 22588 non-null  int64
#  7   warranty              22588 non-null  int64
#  8   mileage               22588 non-null  float64
#  9   gearbox               22588 non-null  object
#  10  fuel_type             22588 non-null  object
#  11  paint                 22588 non-null  object
#  12  seller                22588 non-null  object
#  13  seats                 22588 non-null  int64
#  14  power                 22588 non-null  int64
#  15  engine_size           22588 non-null  int64
#  16  co_emissions          22588 non-null  int64
#  17  drivetrain            22588 non-null  object
#  18  fuel_consumption      22588 non-null  float64
#  19  comfort_convenience   22588 non-null  object
#  20  last_service          22588 non-null  int64
#  21  full_service_history  22588 non-null  int64
#  22  non_smoker_vehicle    22588 non-null  int64
#  23  upholstery            22588 non-null  object
#  24  previous_owner        22588 non-null  int64
#  25  taxi_or_rental_car    22588 non-null  int64
#  26  age                   22588 non-null  float64
# dtypes: float64(3), int64(12), object(12)
# memory usage: 5.3+ MB

# %% [markdown]
# ## Saving the data as a csv file

# %%
df.to_csv("df_cleaned_no_missing_val_no_outliers.csv", index=False)

# %% [markdown]
# ## Reading from the csv file and checking the file

# %%
df=pd.read_csv('df_cleaned_no_missing_val_no_outliers.csv')
df.head().T
# Out:
#                                                                       0  \
# make_model                                          Mercedes-Benz A 160
# make                                                      Mercedes-Benz
# location              P.I. EL PALMAR C/FORJA 6,  11500 PUERTO DE SAN...
# price                                                             16950
# body_type                                                       Compact
# type                                                               Used
# doors                                                                 5
# warranty                                                              2
# mileage                                                        120200.0
# gearbox                                                          Manual
# fuel_type                                                        diesel
# paint                                                          Metallic
# seller                                                           Dealer
# seats                                                                 5
# power                                                                81
# engine_size                                                        1461
# co_emissions                                                        131
# drivetrain                                                        Front
# fuel_consumption                                                    3.8
# comfort_convenience                                                 Low
# last_service                                                          0
# full_service_history                                                  0
# non_smoker_vehicle                                                    0
# upholstery                                                        Cloth
# previous_owner                                                        0
# taxi_or_rental_car                                                    0
# age                                                                 6.0
#
#                                                                       1  \
# make_model                                       Mercedes-Benz A 35 AMG
# make                                                      Mercedes-Benz
# location              Carrer de Provença, 31 Local,  8029 BARCELONA, ES
# price                                                             46990
# body_type                                                       Compact
# type                                                               Used
# doors                                                                 5
# warranty                                                              1
# mileage                                                         18995.0
# gearbox                                                       Automatic
# fuel_type                                                       benzine
# paint                                                             Basic
# seller                                                           Dealer
# seats                                                                 5
# power                                                               185
# engine_size                                                        1991
# co_emissions                                                        122
# drivetrain                                                          4WD
# fuel_consumption                                                    7.3
# comfort_convenience                                                 Low
# last_service                                                          0
# full_service_history                                                  0
# non_smoker_vehicle                                                    0
# upholstery                                                        Cloth
# previous_owner                                                        0
# taxi_or_rental_car                                                    0
# age                                                                 2.0
#
#                                                            2  \
# make_model                            Mercedes-Benz A 45 AMG
# make                                           Mercedes-Benz
# location              CARRIL ARAGONES 4,  30007 CASILLAS, ES
# price                                                  16800
# body_type                                            Compact
# type                                                    Used
# doors                                                      5
# warranty                                                   1
# mileage                                             197000.0
# gearbox                                            Automatic
# fuel_type                                             diesel
# paint                                               Metallic
# seller                                                Dealer
# seats                                                      5
# power                                                    125
# engine_size                                             2143
# co_emissions                                             118
# drivetrain                                               4WD
# fuel_consumption                                         4.9
# comfort_convenience                                      Low
# last_service                                               0
# full_service_history                                       0
# non_smoker_vehicle                                         0
# upholstery                                             Cloth
# previous_owner                                             0
# taxi_or_rental_car                                         0
# age                                                      7.0
#
#                                                           3  \
# make_model                              Mercedes-Benz C 160
# make                                          Mercedes-Benz
# location              Beethovenstr. 89,  42655 Solingen, DE
# price                                                  4690
# body_type                                           Compact
# type                                                   Used
# doors                                                     3
# warranty                                                  0
# mileage                                            165000.0
# gearbox                                              Manual
# fuel_type                                           benzine
# paint                                              Metallic
# seller                                               Dealer
# seats                                                     4
# power                                                    90
# engine_size                                            1799
# co_emissions                                             95
# drivetrain                                             Rear
# fuel_consumption                                        8.2
# comfort_convenience                                  Medium
# last_service                                              1
# full_service_history                                      1
# non_smoker_vehicle                                        1
# upholstery                                            Cloth
# previous_owner                                            0
# taxi_or_rental_car                                        0
# age                                                    17.0
#
#                                                                     4
# make_model                                      Mercedes-Benz CLA 180
# make                                                    Mercedes-Benz
# location              CR PATERNA-LA CAÑADA, KM. 2,  46980 PATERNA, ES
# price                                                           22550
# body_type                                                     Compact
# type                                                             Used
# doors                                                               5
# warranty                                                            1
# mileage                                                       83339.0
# gearbox                                                        Manual
# fuel_type                                                      diesel
# paint                                                           Basic
# seller                                                         Dealer
# seats                                                               5
# power                                                              90
# engine_size                                                      1595
# co_emissions                                                       95
# drivetrain                                                       Rear
# fuel_consumption                                                  8.2
# comfort_convenience                                            Medium
# last_service                                                        0
# full_service_history                                                0
# non_smoker_vehicle                                                  0
# upholstery                                                      Cloth
# previous_owner                                                      0
# taxi_or_rental_car                                                  0
# age                                                               4.0

# %% [markdown]
# ## Getting Dummy Variables with Pandas

# %%
df_dummy = pd.get_dummies(data = df, drop_first=True).astype(int)
df_dummy.T
# Out:
#                              0      1       2       3      4      5      \
# price                        16950  46990   16800    4690  22550  26900
# doors                            5      5       5       3      5      5
# warranty                         2      1       1       0      1      2
# mileage                     120200  18995  197000  165000  83339  48900
# seats                            5      5       5       4      5      5
# ...                            ...    ...     ...     ...    ...    ...
# drivetrain_Rear                  0      0       0       1      1      0
# comfort_convenience_Low          1      1       1       0      0      1
# comfort_convenience_Medium       0      0       0       1      1      0
# upholstery_Leather               0      0       0       0      0      0
# upholstery_Other                 0      0       0       0      0      0
#
#                             6      7      8      9      ...  22578  22579  \
# price                       23900  14200  37999  23999  ...  33500  38000
# doors                           5      5      5      5  ...      4      4
# warranty                        1      1      1      1  ...      1      0
# mileage                     21854  99016  90000  25914  ...  53000  44873
# seats                           5      5      5      5  ...      5      5
# ...                           ...    ...    ...    ...  ...    ...    ...
# drivetrain_Rear                 0      0      0      0  ...      0      0
# comfort_convenience_Low         1      1      1      1  ...      0      0
# comfort_convenience_Medium      0      0      0      0  ...      0      0
# upholstery_Leather              0      0      0      0  ...      1      1
# upholstery_Other                0      0      0      0  ...      0      0
#
#                             22580  22581   22582   22583  22584   22585  \
# price                       27190  27190   13000    4999  37600    5499
# doors                           4      4       5       4      4       4
# warranty                        1      1       0       1      1       0
# mileage                     93757  93757  114000  166512  40345  145000
# seats                           5      5       5       5      4       5
# ...                           ...    ...     ...     ...    ...     ...
# drivetrain_Rear                 0      0       0       0      0       0
# comfort_convenience_Low         1      1       0       1      1       1
# comfort_convenience_Medium      0      0       1       0      0       0
# upholstery_Leather              0      0       0       0      0       0
# upholstery_Other                0      0       0       0      0       0
#
#                             22586   22587
# price                        7300    4440
# doors                           3       4
# warranty                        2       0
# mileage                     96000  230047
# seats                           4       5
# ...                           ...     ...
# drivetrain_Rear                 0       0
# comfort_convenience_Low         1       0
# comfort_convenience_Medium      0       1
# upholstery_Leather              0       1
# upholstery_Other                0       0
#
# [7279 rows x 22588 columns]

# %% [markdown]
# ## Saving the dummified data as csv

# %%
df_dummy.to_csv("df_cleaned_no_missing_val_no_outliers_dummy.csv", index=False)

# %% [markdown]
# ## The data is ready for ML modelling
